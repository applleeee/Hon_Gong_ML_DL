# %% [markdown]
# * **지도 학습**은 입력과 타깃(정답)을 전달하여 모델을 훈련한 다음 새로운 데이터를 예측하는 데 활용. k-최근접 이웃이 지도 학습 알고리즘.
# * **비지도 학습**은 타깃 데이터가 없음. 따라서 무엇을 예측하는 것이 아니라 입력 데이터에서 어떤 특징을 찾는 데 주로 활용.
# * **훈련 세트**는 모델을 훈련할 때 사용하는 데이터. 보통 클수록 좋음.
# * **테스트 세트**는 전체 데이터에서 20~30%를 테스트 세트로 주로 사용. 전체 데이터가 아주 크다면 더 적은 비율로도 가능.

# %% [markdown]
# # Numpy
# * **seed()**는 넘파이에서 난수를 생성하기 위한 정수 초깃값을 지정. 이 값이 같으면 동일한 난수를 얻을 수 있음. 랜덤 함수의 결과를 동일하게 재현하고 싶을 때 사용.
# * **arange()**는 일정한 간격의 정수 또는 실수 배열을 만듦. 기본 간격은 1. 매개변수가 하나이면 종료 숫자를 의미. 0부터 입력한 숫자까지 배열을 생성. 종료 숫자는 배열에 포함되지 않음. 매개변수가 두 개이면 시작, 종료 숫자를 나타냄. 매개변수가 세 개이면 마지막 매개변수가 간격을 나타냄.
# ```
# print(np.arange(3))
# # [0, 1, 2]
# print(np.arange(1,3))
# # [1, 2]
# print(np.arange(1,3,0.2))
# # [1. , 1.2, 1.4, 1.6... 2.8]
# ```
# * **shuffle()**은 주어진 배열을 랜덤하게 섞음. 다차원 배열인 경우 첫 번째 행에 대해서만 섞음.

# %%
from sklearn.neighbors import KNeighborsClassifier

bream_length = [25.4, 26.3, 26.5, 29.0, 29.0, 29.7, 29.7, 30.0, 30.0, 30.7, 31.0, 31.0,
                31.5, 32.0, 32.0, 32.0, 33.0, 33.0, 33.5, 33.5, 34.0, 34.0, 34.5, 35.0,
                35.0, 35.0, 35.0, 36.0, 36.0, 37.0, 38.5, 38.5, 39.5, 41.0, 41.0]
bream_weight = [242.0, 290.0, 340.0, 363.0, 430.0, 450.0, 500.0, 390.0, 450.0, 500.0, 475.0, 500.0,
                500.0, 340.0, 600.0, 600.0, 700.0, 700.0, 610.0, 650.0, 575.0, 685.0, 620.0, 680.0,
                700.0, 725.0, 720.0, 714.0, 850.0, 1000.0, 920.0, 955.0, 925.0, 975.0, 950.0]

smelt_length = [9.8, 10.5, 10.6, 11.0, 11.2, 11.3, 11.8, 11.8, 12.0, 12.2, 12.4, 13.0, 14.3, 15.0]
smelt_weight = [6.7, 7.5, 7.0, 9.7, 9.8, 8.7, 10.0, 9.9, 9.8, 12.2, 13.4, 12.2, 19.7, 19.9]

length = bream_length + smelt_length
weight = bream_weight +smelt_weight

fish_data = [[l, w] for l, w in zip(length, weight)]
fish_target = [1] * 35 + [0] * 14

kn = KNeighborsClassifier()

train_input = fish_data[:35]
train_target = fish_target[:35]
test_input = fish_data[35:]
test_target = fish_target[35:]

kn.fit(train_input, train_target)
kn.score(test_input, test_target)
# Out:
# 0.0

# %%
import numpy as np

input_arr = np.array(fish_data)
target_arr = np.array(fish_target)

print(input_arr)
# Out:
# [[  25.4  242. ]
#  [  26.3  290. ]
#  [  26.5  340. ]
#  [  29.   363. ]
#  [  29.   430. ]
#  [  29.7  450. ]
#  [  29.7  500. ]
#  [  30.   390. ]
#  [  30.   450. ]
#  [  30.7  500. ]
#  [  31.   475. ]
#  [  31.   500. ]
#  [  31.5  500. ]
#  [  32.   340. ]
#  [  32.   600. ]
#  [  32.   600. ]
#  [  33.   700. ]
#  [  33.   700. ]
#  [  33.5  610. ]
#  [  33.5  650. ]
#  [  34.   575. ]
#  [  34.   685. ]
#  [  34.5  620. ]
#  [  35.   680. ]
#  [  35.   700. ]
#  [  35.   725. ]
#  [  35.   720. ]
#  [  36.   714. ]
#  [  36.   850. ]
#  [  37.  1000. ]
#  [  38.5  920. ]
#  [  38.5  955. ]
#  [  39.5  925. ]
#  [  41.   975. ]
#  [  41.   950. ]
#  [   9.8    6.7]
#  [  10.5    7.5]
#  [  10.6    7. ]
#  [  11.     9.7]
#  [  11.2    9.8]
#  [  11.3    8.7]
#  [  11.8   10. ]
#  [  11.8    9.9]
#  [  12.     9.8]
#  [  12.2   12.2]
#  [  12.4   13.4]
#  [  13.    12.2]
#  [  14.3   19.7]
#  [  15.    19.9]]

# %%
print(input_arr.shape) # (샘플 수, 특성 수) 출력
# Out:
# (49, 2)

# %%
np.random.seed(42)
index = np.arange(49) # 0부터 N-1까지 증가하는 배열 생성
np.random.shuffle(index)

# %%
print(input_arr[[1,3]])
# Out:
# [[ 26.3 290. ]
#  [ 29.  363. ]]

# %%
import matplotlib.pyplot as plt

train_input = input_arr[index[:35]]
train_target = target_arr[index[:35]]

test_input = input_arr[index[35:]]
test_target = target_arr[index[35:]]

plt.scatter(train_input[:,0], train_input[:,1], c='blue', label='Train', alpha=0.7)
plt.scatter(test_input[:,0], test_input[:,1], c='red', label='Test', alpha=0.7)

plt.xlabel('length')
plt.ylabel('weight')
plt.legend()
plt.show()

# %%
kn.fit(train_input, train_target)
kn.score(test_input, test_target)
# Out:
# 1.0

# %%
kn.predict(test_input)
test_target
# Out:
# array([0, 0, 1, 0, 1, 1, 1, 0, 1, 1, 0, 1, 1, 0])
